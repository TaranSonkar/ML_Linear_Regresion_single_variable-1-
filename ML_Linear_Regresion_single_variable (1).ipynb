# %% [markdown]
# #IMPORT LIB......

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import linear_model

# %% [markdown]
# #USING HOUSE PRICING DATA SET
# #PREDETED HOUSES PRICE ACCORDING TO HOUSE AREA

# %%
df=pd.read_csv('/content/House Pricing final.csv')
df
# Out:
#       Unnamed: 0  Sale Price
# 0           1461      100225
# 1           1462       90609
# 2           1463       87605
# 3           1464       87417
# 4           1465       48733
# ...          ...         ...
# 1446        2907       90099
# 1447        2908       83682
# 1448        2909      105110
# 1449        2910      122344
# 1450        2911       96766
#
# [1451 rows x 2 columns]

# %% [markdown]
# #SET A COLUMNS NAME

# %%
df.columns=["Area","Sales Price"]

# %%
df
# Out:
#       Area  Sales Price
# 0     1461       100225
# 1     1462        90609
# 2     1463        87605
# 3     1464        87417
# 4     1465        48733
# ...    ...          ...
# 1446  2907        90099
# 1447  2908        83682
# 1448  2909       105110
# 1449  2910       122344
# 1450  2911        96766
#
# [1451 rows x 2 columns]

# %% [markdown]
# #CREATE A PLOT

# %%
#plt.scatter(df['Area'],df['Sales Price'])
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df['Area'],df['Sales Price'],marker='+',color='M')

# %%
new_df=df.drop('Sales Price',axis='columns')

# %%
new_df
# Out:
#       Area
# 0     1461
# 1     1462
# 2     1463
# 3     1464
# 4     1465
# ...    ...
# 1446  2907
# 1447  2908
# 1448  2909
# 1449  2910
# 1450  2911
#
# [1451 rows x 1 columns]

# %%
model=linear_model.LinearRegression()

# %%
model.fit(new_df,df['Sales Price'])
# Out:
# LinearRegression()

# %%
model.predict([[5000]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([106086.86870769])

# %%
model.coef_
# Out:
# array([-1.74361223])

# %%
model.intercept_
# Out:
# 114804.92985555898

# %% [markdown]
# ![WhatsApp Image 2022-01-22 at 12.16.32 AM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #BACKED MODEL PROCESS
# #ACCORDING TO MATH FORMULA
#
# M=COEF_
#
# X= AREA
#
# B= INTERSEPT

# %% [markdown]
# #y=m*X+b

# %%
-1.74361223*5000+114804.92985555898
# Out:
# 106086.86870555897

# %% [markdown]
# #PREDICT THE PRICE ACCORDING TO AREA

# %%
p=model.predict(new_df)
p
# Out:
# array([112257.51238815, 112255.76877592, 112254.02516369, ...,
#        109732.76187973, 109731.0182675 , 109729.27465527])

# %%
new_df["new price"]=p

# %%
new_df
# Out:
#       Area      new price
# 0     1461  112257.512388
# 1     1462  112255.768776
# 2     1463  112254.025164
# 3     1464  112252.281551
# 4     1465  112250.537939
# ...    ...            ...
# 1446  2907  109736.249104
# 1447  2908  109734.505492
# 1448  2909  109732.761880
# 1449  2910  109731.018267
# 1450  2911  109729.274655
#
# [1451 rows x 2 columns]

# %%
pd.DataFrame(new_df).T
# Out:
#                     0              1     ...           1449           1450
# Area         1461.000000    1462.000000  ...    2910.000000    2911.000000
# new price  112257.512388  112255.768776  ...  109731.018267  109729.274655
#
# [2 rows x 1451 columns]
